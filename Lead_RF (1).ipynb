# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

file_path = 'Lead_data.csv' 
data = pd.read_csv(file_path)

data = data.drop('ID', axis=1)

X = data.drop('Bandgap', axis=1) 
y = data['Bandgap']  

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=42)

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)  
rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print(f'Mean Squared Error (Random Forest): {mse_rf}')
print(f'R-squared (Random Forest Accuracy): {r2_rf}')

plt.scatter(y_test, y_pred_rf, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linewidth=2)  
plt.xlabel('Actual Bandgap')
plt.ylabel('Predicted Bandgap')
plt.title('Random Forest: Actual vs Predicted Bandgap')

plt.show()
# Out:
# Mean Squared Error (Random Forest): 0.008939158461538452
# R-squared (Random Forest Accuracy): 0.9371072122695071
